# %%
from gen_shape_fig import *

import warnings
warnings.filterwarnings("ignore")

# %%
output = gen_shape_fig('405209', 'Acheron River at Taggerty', start_lt=1, end_lt=7, parallel_nodes=8)
print('%.2f minutes' % output['execution_time_min'])
# Out:
# Loading data
# 	Loading data for 405209/muthre from lead-time 1 to 7
# 	obs shape: (1932,), fcst_ens shape: (1932, 100), clim shape: (1932, 508)
# Starting shape figure...
# 	Generating results
# 	Generating figure
# 	Saving figure
# 	Saving output
# 12.97 minutes
