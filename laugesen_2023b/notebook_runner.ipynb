# %%
from shape_figure import shape_figure
from location_figure import location_figure
from regime_figure import regime_figure
from hydrograph_clim_fdc_figure import hydrograph_clim_fdc_figure

import warnings
warnings.filterwarnings("ignore")

# %%
parallel_nodes = 8
shape_resolution = 0.02
location_resolution = 1
regime_resolution = 0.005

# awrc = '405219'
# name = 'Goulburn River at Dohertys'
# area = 700.2

# awrc = '401012'
# name = 'Murray River at Biggera'
# area = 1257

awrc = '405209'
name = 'Acheron River at Tagerty'
area = 629.4

start_lt=1
end_lt=7

# %%
hydrograph_clim_fdc_output = hydrograph_clim_fdc_figure(awrc, name, start_lt, end_lt, area, parallel_nodes)
# Out:
# Loading data
# 	Loading data for 405209/muthre from lead-time 1 to 7
# 	obs shape: (1932,), fcst_ens shape: (1932, 100), clim shape: (1932, 508)
# Starting shape figure...
# 	Saving figure
# 	Saving output
# dict_keys(['obs', 'awrc', 'name', 'start_lt', 'end_lt', 'area', 'figure_name', 'obs_dataframe'])

# %%
shape_output = shape_figure(awrc, name, start_lt, end_lt, area, k_step=shape_resolution, parallel_nodes=parallel_nodes)
print('%.2f minutes' % shape_output['execution_time_min'])
# Out:
# Loading data
# 	Loading data for 405209/muthre from lead-time 1 to 7
# 	obs shape: (1932,), fcst_ens shape: (1932, 100), clim shape: (1932, 508)
# Starting shape figure...
# 	Generating results
# 		10% complete with 23.1 minutes remaining
# 		20% complete with 21.8 minutes remaining
# 		30% complete with 18.3 minutes remaining
# 		40% complete with 15.1 minutes remaining
# 		50% complete with 12.4 minutes remaining
# 		60% complete with 10.0 minutes remaining
# 		70% complete with 7.5 minutes remaining
# 		80% complete with 5.1 minutes remaining
# 		90% complete with 2.6 minutes remaining
# 	Generating figure
# 	Saving figure
# 	Saving output
# dict_keys(['obs', 'fcst', 'clim', 'awrc', 'name', 'start_lt', 'end_lt', 'parallel_nodes', 'k_step', 'area', 'figure_name', 'damages_title', 'ruv_only', 'all_results', 'damages_results', 'max_obs', 'decision_definition', 'steepness_params', 'execution_time_min'])
# 25.72 minutes

# %%
location_output = location_figure(awrc, name, start_lt, end_lt, area, q_step=location_resolution, parallel_nodes=parallel_nodes)
print('%.2f minutes' % location_output['execution_time_min'])
# Out:
# Loading data
# 	Loading data for 405209/muthre from lead-time 1 to 7
# 	obs shape: (1932,), fcst_ens shape: (1932, 100), clim shape: (1932, 508)
# Starting location figure...
# 	Generating results
# 		20% complete with 15.9 minutes remaining
# 		40% complete with 12.1 minutes remaining
# 		60% complete with 8.3 minutes remaining
# 		80% complete with 4.3 minutes remaining
# 	Generating figure
# 	Saving figure
# 	Saving output
# dict_keys(['obs', 'fcst', 'clim', 'awrc', 'name', 'start_lt', 'end_lt', 'parallel_nodes', 'q_step', 'area', 'figure_name', 'damages_title', 'ruv_only', 'all_results', 'damages_results', 'max_obs', 'decision_definition', 'thresholds', 'execution_time_min'])
# 21.76 minutes

# %%
regime_output = regime_figure(awrc, name, start_lt, end_lt, area, alpha_step=regime_resolution, parallel_nodes=parallel_nodes)
print('%.2f minutes' % regime_output['execution_time_min'])
# Out:
# Loading data
# 	Loading data for 405209/muthre from lead-time 1 to 7
# 	obs shape: (1932,), fcst_ens shape: (1932, 100), clim shape: (1932, 508)
# Starting regime figure...
# 	Generating results
# 		25% complete with 23.3 minutes remaining
# 		50% complete with 15.6 minutes remaining
# 		75% complete with 7.8 minutes remaining
# 	Generating figure
# 	Saving figure
# 	Saving output
# dict_keys(['obs', 'fcst', 'clim', 'awrc', 'name', 'start_lt', 'end_lt', 'parallel_nodes', 'alpha_step', 'area', 'figure_name', 'damages_title', 'ruv_only', 'all_results', 'damages_results', 'max_obs', 'decision_definition', 'damage_functions', 'execution_time_min'])
# 29.31 minutes
